# %%
# %%bash
#
# head traffic.json
# Out:
# {
#   "meta" : {
#     "view" : {
#       "id" : "4mse-ku6q",
#       "name" : "Traffic Violations",
#       "averageRating" : 0,
#       "category" : "Public Safety",
#       "createdAt" : 1403103517,
#       "description" : "This dataset contains traffic violation information from all electronic traffic violations issued in the County.  Any information that can be used to uniquely identify the vehicle, the vehicle owner or the officer issuing the violation will not be published.\r\n\r\nUpdate Frequency:  Daily",
#       "displayType" : "table",

# %%
# %%bash
#
# grep -E '^ {2}"' traffic.json
# Out:
#   "meta" : {
#   "data" : [ [ 2118167, "EE8BC302-660F-48C4-B422-17427ECE821F", 2118167, 1482239054, "498050", 1482239054, "498050", null, "2013-09-24T00:00:00", "17:11:00", "MCP", "3rd district, Silver Spring", "DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION", "8804 FLOWER AVE", null, null, "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "MD", "02 - Automobile", "2008", "FORD", "4S", "BLACK", "Citation", "13-401(h)", "Transportation Article", "No", "BLACK", "M", "TAKOMA PARK", "MD", "MD", "A - Marked Patrol", [ null, null, null, null, null ] ]

# %%
# %%bash
#
# grep -E '^ {2,6}"' traffic.json
# Out:
#   "meta" : {
#     "view" : {
#       "id" : "4mse-ku6q",
#       "name" : "Traffic Violations",
#       "averageRating" : 0,
#       "category" : "Public Safety",
#       "createdAt" : 1403103517,
#       "description" : "This dataset contains traffic violation information from all electronic traffic violations issued in the County.  Any information that can be used to uniquely identify the vehicle, the vehicle owner or the officer issuing the violation will not be published.\r\n\r\nUpdate Frequency:  Daily",
#       "displayType" : "table",
#       "downloadCount" : 51172,
#       "hideFromCatalog" : false,
#       "hideFromDataJson" : false,
#       "iconUrl" : "fileId:r41tDc239M1FL75LFwXFKzFCWqr8mzMeMTYXiA24USM",
#       "indexUpdatedAt" : 1490087643,
#       "newBackend" : false,
#       "numberOfComments" : 0,
#       "oid" : 8890705,
#       "provenance" : "official",
#       "publicationAppendEnabled" : false,
#       "publicationDate" : 1411040702,
#       "publicationGroup" : 1620779,
#       "publicationStage" : "published",
#       "rowClass" : "",
#       "rowsUpdatedAt" : 1490087468,
#       "rowsUpdatedBy" : "ajn4-zy65",
#       "tableId" : 1722160,
#       "totalTimesRated" : 0,
#       "viewCount" : 18846,
#       "viewLastModified" : 1434558076,
#       "viewType" : "tabular",
#       "columns" : [ {
#       "disabledFeatureFlags" : [ "allow_comments" ],
#       "grants" : [ {
#       "metadata" : {
#       "owner" : {
#       "query" : {
#       "rights" : [ "read" ],
#       "tableAuthor" : {
#       "tags" : [ "traffic", "stop", "violations", "electronic issued." ],
#       "flags" : [ "default", "restorable", "restorePossibleForType" ]
#   "data" : [ [ 2118167, "EE8BC302-660F-48C4-B422-17427ECE821F", 2118167, 1482239054, "498050", 1482239054, "498050", null, "2013-09-24T00:00:00", "17:11:00", "MCP", "3rd district, Silver Spring", "DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION", "8804 FLOWER AVE", null, null, "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "MD", "02 - Automobile", "2008", "FORD", "4S", "BLACK", "Citation", "13-401(h)", "Transportation Article", "No", "BLACK", "M", "TAKOMA PARK", "MD", "MD", "A - Marked Patrol", [ null, null, null, null, null ] ]

# %%
import ijson

# %%
filename = "traffic.json"
with open(filename, 'r') as f:
    objects = ijson.items(f, 'meta.view.columns.item')
    columns = list(objects)

# %%
print(columns[0])
# Out:
# {'id': -1, 'name': 'sid', 'dataTypeName': 'meta_data', 'fieldName': ':sid', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}, 'flags': ['hidden']}

# %%
columns
# Out:
# [{'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'sid',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'id',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'position',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':created_at',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'created_at',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':created_meta',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'created_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':updated_at',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'updated_at',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':updated_meta',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'updated_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'dataTypeName': 'meta_data',
#   'fieldName': ':meta',
#   'flags': ['hidden'],
#   'format': {},
#   'id': -1,
#   'name': 'meta',
#   'position': 0,
#   'renderTypeName': 'meta_data'},
#  {'cachedContents': {'largest': '2017-03-20T00:00:00',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': '2012-01-01T00:00:00',
#    'top': [{'count': 20, 'item': '2017-01-25T00:00:00'},
#     {'count': 19, 'item': '2017-01-31T00:00:00'},
#     {'count': 18, 'item': '2017-02-01T00:00:00'},
#     {'count': 17, 'item': '2017-02-03T00:00:00'},
#     {'count': 16, 'item': '2017-02-06T00:00:00'},
#     {'count': 15, 'item': '2017-02-07T00:00:00'},
#     {'count': 14, 'item': '2017-02-08T00:00:00'},
#     {'count': 13, 'item': '2017-02-10T00:00:00'},
#     {'count': 12, 'item': '2017-02-14T00:00:00'},
#     {'count': 11, 'item': '2017-02-15T00:00:00'},
#     {'count': 10, 'item': '2017-02-16T00:00:00'},
#     {'count': 9, 'item': '2017-02-17T00:00:00'},
#     {'count': 8, 'item': '2017-02-18T00:00:00'},
#     {'count': 7, 'item': '2017-02-20T00:00:00'},
#     {'count': 6, 'item': '2017-02-21T00:00:00'},
#     {'count': 5, 'item': '2017-02-22T00:00:00'},
#     {'count': 4, 'item': '2017-02-23T00:00:00'},
#     {'count': 3, 'item': '2017-02-24T00:00:00'},
#     {'count': 2, 'item': '2017-02-27T00:00:00'},
#     {'count': 1, 'item': '2017-02-28T00:00:00'}]},
#   'dataTypeName': 'calendar_date',
#   'description': 'Date of the traffic violation.',
#   'fieldName': 'date_of_stop',
#   'format': {'align': 'left', 'view': 'date'},
#   'id': 167291006,
#   'name': 'Date Of Stop',
#   'position': 2,
#   'renderTypeName': 'calendar_date',
#   'tableColumnId': 20333361,
#   'width': 97},
#  {'cachedContents': {'largest': '23:59:00',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': '00:00:00',
#    'top': [{'count': 20, 'item': '18:00:00'},
#     {'count': 19, 'item': '22:47:00'},
#     {'count': 18, 'item': '01:37:00'},
#     {'count': 17, 'item': '07:29:00'},
#     {'count': 16, 'item': '18:02:00'},
#     {'count': 15, 'item': '07:54:00'},
#     {'count': 14, 'item': '00:10:00'},
#     {'count': 13, 'item': '00:22:00'},
#     {'count': 12, 'item': '08:04:00'},
#     {'count': 11, 'item': '14:27:00'},
#     {'count': 10, 'item': '23:52:00'},
#     {'count': 9, 'item': '21:51:00'},
#     {'count': 8, 'item': '23:32:00'},
#     {'count': 7, 'item': '16:30:00'},
#     {'count': 6, 'item': '16:32:00'},
#     {'count': 5, 'item': '17:51:00'},
#     {'count': 4, 'item': '22:45:00'},
#     {'count': 3, 'item': '19:57:00'},
#     {'count': 2, 'item': '17:26:00'},
#     {'count': 1, 'item': '18:20:00'}]},
#   'dataTypeName': 'text',
#   'description': 'Time of the traffic violation.',
#   'fieldName': 'time_of_stop',
#   'format': {'align': 'left'},
#   'id': 167291007,
#   'name': 'Time Of Stop',
#   'position': 3,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333363,
#   'width': 89},
#  {'cachedContents': {'largest': 'MCP',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'MCP',
#    'top': [{'count': 20, 'item': 'MCP'}]},
#   'dataTypeName': 'text',
#   'description': 'Agency issuing the traffic violation.  (Example: MCP is Montgomery County Police)',
#   'fieldName': 'agency',
#   'format': {'align': 'left'},
#   'id': 167291008,
#   'name': 'Agency',
#   'position': 4,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333364,
#   'width': 63},
#  {'cachedContents': {'largest': 'Headquarters and Special Operations',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': '1st district, Rockville',
#    'top': [{'count': 20, 'item': '3rd district, Silver Spring'},
#     {'count': 19, 'item': '1st district, Rockville'},
#     {'count': 18, 'item': '2nd district, Bethesda'},
#     {'count': 17, 'item': '4th district, Wheaton'},
#     {'count': 16, 'item': '5th district, Germantown'},
#     {'count': 15, 'item': '6th district, Gaithersburg / Montgomery Village'},
#     {'count': 14, 'item': 'Headquarters and Special Operations'}]},
#   'dataTypeName': 'text',
#   'description': 'Court code representing the district of assignment of the officer. \nR15 = 1st district, Rockville\nB15 = 2nd district, Bethesda\nSS15 = 3rd district, Silver Spring\nWG15 = 4th district, Wheaton\nG15 = 5th district, Germantown\nM15 = 6th district, Gaithersburg / Montgomery Village\nHQ15 = Headquarters and Special Operations',
#   'fieldName': 'subagency',
#   'format': {'align': 'left'},
#   'id': 167291009,
#   'name': 'SubAgency',
#   'position': 5,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333366,
#   'width': 259},
#  {'cachedContents': {'largest': 'XX',
#    'non_null': 1067822,
#    'null': 8,
#    'smallest': ', ATTEMPTING TO DRIVE MOTOR VEHICLE ON HIGHWAY WITHOUT REQUIRED LICENSE AND AUTHORIZATION',
#    'top': [{'count': 20,
#      'item': 'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION'},
#     {'count': 19,
#      'item': 'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS'},
#     {'count': 18,
#      'item': 'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER'},
#     {'count': 17,
#      'item': 'FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND'},
#     {'count': 16,
#      'item': 'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE'},
#     {'count': 15,
#      'item': 'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION'},
#     {'count': 14, 'item': 'DRIVER FAILURE TO STOP AT STOP SIGN LINE'},
#     {'count': 13, 'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH'},
#     {'count': 12, 'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH'},
#     {'count': 11,
#      'item': 'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE'},
#     {'count': 10, 'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH'},
#     {'count': 9,
#      'item': 'FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAMPS, ILLUMINATING DEVICE IN UNFAVORABLE VISIBILITY COND'},
#     {'count': 8, 'item': 'STOP LIGHTS (*)'},
#     {'count': 7, 'item': 'WINDOW TINT'},
#     {'count': 6, 'item': 'Stop Lights'},
#     {'count': 5, 'item': 'Headlights (*)'},
#     {'count': 4, 'item': 'Stop Lights (*)'},
#     {'count': 3, 'item': 'HEADLIGHTS (*)'},
#     {'count': 2,
#      'item': 'DRIVING MOTOR VEHICLE OFF ROADWAY WHILE PASSING VEHICLE'},
#     {'count': 1, 'item': 'DRIVING OFF ROADWAY WHILE PASSING VEHICLE'}]},
#   'dataTypeName': 'text',
#   'description': 'Text description of the specific charge.',
#   'fieldName': 'description',
#   'format': {'align': 'left'},
#   'id': 167291010,
#   'name': 'Description',
#   'position': 6,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333367,
#   'width': 720},
#  {'cachedContents': {'largest': '�MIDDLEBROOK RD AT GERMANTOWN RD',
#    'non_null': 1067828,
#    'null': 2,
#    'smallest': '`10141 COLESVILLE ROAD / PARKING LOT',
#    'top': [{'count': 20, 'item': 'RIVER RD AND GOLDSBORO RD'},
#     {'count': 19, 'item': 'RIVER RD/GOLDSBORO RD'},
#     {'count': 18, 'item': 'RIVER RD @ GOLDSBORO RD'},
#     {'count': 17, 'item': '355@ GUNNERS BRANCH DR'},
#     {'count': 16, 'item': 'MATENY RD @ DAIRYMAID DRIVE'},
#     {'count': 15, 'item': 'GERMANTOWN RD @ DAWSON FARM RD'},
#     {'count': 14, 'item': '118/ CLOPPER'},
#     {'count': 13, 'item': 'GEORGIA AVE @ ROSMOOR BLVD'},
#     {'count': 12, 'item': '11700 GEORGIA AVE4D'},
#     {'count': 11, 'item': 'MONT VILL AVE / RUSSELL AVE'},
#     {'count': 10, 'item': 'RIVER RD @ 495'},
#     {'count': 9, 'item': '12700 BLOCK VEIRS MILL RD'},
#     {'count': 8, 'item': 'SHADY GROVE RD @  GAITHER RD'},
#     {'count': 7, 'item': 'BETHESDA CHURCH RD AT DAMASCUS ELEM SCH'},
#     {'count': 6, 'item': '270/SHADY GROVE RD'},
#     {'count': 5, 'item': 'DEMOCRACY BLVD/I-270 SPUR'},
#     {'count': 4, 'item': 'SHADY GROVE RD/MILL RUN DR'},
#     {'count': 3, 'item': 'NB GEORGIA AVE AND CONNECTICUT AVE'},
#     {'count': 2, 'item': 'BROOKVILLE RD/WOODBINE ST'},
#     {'count': 1, 'item': 'W. CERDAR LN/ CAMBERLEY AVE'}]},
#   'dataTypeName': 'text',
#   'description': 'Location of the violation, usually an address or intersection.',
#   'fieldName': 'location',
#   'format': {'align': 'left'},
#   'id': 167291011,
#   'name': 'Location',
#   'position': 7,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333369,
#   'width': 302},
#  {'cachedContents': {'average': '39.07156962879637',
#    'largest': '40.1118216666667',
#    'non_null': 980784,
#    'null': 87046,
#    'smallest': '-94.6109883333333',
#    'sum': '38320770.346809415284333',
#    'top': [{'count': 20, 'item': '39.0611333333333'},
#     {'count': 19, 'item': '39.0584266666667'},
#     {'count': 18, 'item': '39.1732183333333'},
#     {'count': 17, 'item': '39.1641316666667'},
#     {'count': 16, 'item': '39.10273'},
#     {'count': 15, 'item': '39.04836'},
#     {'count': 14, 'item': '39.1185668333333'},
#     {'count': 13, 'item': '39.073645'},
#     {'count': 12, 'item': '39.031945'},
#     {'count': 11, 'item': '39.181995'},
#     {'count': 10, 'item': '39.1876583333333'},
#     {'count': 9, 'item': '39.0644266666667'},
#     {'count': 8, 'item': '39.096275'},
#     {'count': 7, 'item': '39.1615416666667'},
#     {'count': 6, 'item': '39.0366416666667'},
#     {'count': 5, 'item': '39.0406833333333'},
#     {'count': 4, 'item': '38.9970816666667'},
#     {'count': 3, 'item': '38.992695'},
#     {'count': 2, 'item': '38.9926883333333'}]},
#   'dataTypeName': 'number',
#   'description': 'Latitude location of the traffic violation.',
#   'fieldName': 'latitude',
#   'format': {'align': 'left',
#    'noCommas': 'false',
#    'precisionStyle': 'standard'},
#   'id': 167291012,
#   'name': 'Latitude',
#   'position': 8,
#   'renderTypeName': 'number',
#   'tableColumnId': 20333562,
#   'width': 100},
#  {'cachedContents': {'average': '-77.10009572184495',
#    'largest': '41.5431599333333',
#    'non_null': 980784,
#    'null': 87046,
#    'smallest': '-77.820825',
#    'sum': '-75618540.2824539814633',
#    'top': [{'count': 20, 'item': '-77.0529633333333'},
#     {'count': 19, 'item': '-77.0479483333333'},
#     {'count': 18, 'item': '-77.2749966666667'},
#     {'count': 17, 'item': '-77.2854233333333'},
#     {'count': 16, 'item': '-77.0767416666667'},
#     {'count': 15, 'item': '-77.05185'},
#     {'count': 14, 'item': '-77.182816'},
#     {'count': 13, 'item': '-77.0664716666667'},
#     {'count': 12, 'item': '-77.0491'},
#     {'count': 11, 'item': '-77.231645'},
#     {'count': 10, 'item': '-77.250475'},
#     {'count': 9, 'item': '-77.073985'},
#     {'count': 8, 'item': '-77.202135'},
#     {'count': 7, 'item': '-77.280335'},
#     {'count': 6, 'item': '-77.0613516666667'},
#     {'count': 5, 'item': '-77.0540533333333'},
#     {'count': 4, 'item': '-77.03358'},
#     {'count': 3, 'item': '-77.0240416666667'},
#     {'count': 2, 'item': '-77.02404'}]},
#   'dataTypeName': 'number',
#   'description': 'Longitude location of the traffic violation.',
#   'fieldName': 'longitude',
#   'format': {'align': 'left',
#    'noCommas': 'false',
#    'precisionStyle': 'standard'},
#   'id': 167291013,
#   'name': 'Longitude',
#   'position': 9,
#   'renderTypeName': 'number',
#   'tableColumnId': 20333563,
#   'width': 120},
#  {'cachedContents': {'largest': 'No',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}]},
#   'dataTypeName': 'text',
#   'description': 'If traffic violation involved an accident.',
#   'fieldName': 'accident',
#   'format': {'align': 'left'},
#   'id': 167291014,
#   'name': 'Accident',
#   'position': 10,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333390,
#   'width': 70},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If traffic violation involved a seat belt violation.',
#   'fieldName': 'belts',
#   'format': {'align': 'left'},
#   'id': 167291015,
#   'name': 'Belts',
#   'position': 11,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333391,
#   'width': 57},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If traffic violation involved Personal Injury.',
#   'fieldName': 'personal_injury',
#   'format': {'align': 'left'},
#   'id': 167291016,
#   'name': 'Personal Injury',
#   'position': 12,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333392,
#   'width': 86},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If traffic violation involved Property Damage.',
#   'fieldName': 'property_damage',
#   'format': {'align': 'left'},
#   'id': 167291017,
#   'name': 'Property Damage',
#   'position': 13,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333393,
#   'width': 98},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If traffic violation involved a fatality.',
#   'fieldName': 'fatal',
#   'format': {'align': 'left'},
#   'id': 167291018,
#   'name': 'Fatal',
#   'position': 14,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333394,
#   'width': 50},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If driver holds a Commercial Drivers License.',
#   'fieldName': 'commercial_license',
#   'format': {'align': 'left'},
#   'id': 167291019,
#   'name': 'Commercial License',
#   'position': 15,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333395,
#   'width': 118},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If the traffic violation involved hazardous materials.',
#   'fieldName': 'hazmat',
#   'format': {'align': 'left'},
#   'id': 167291020,
#   'name': 'HAZMAT',
#   'position': 16,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333396,
#   'width': 65},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If the vehicle committing the traffic violation is a commercial vehicle.',
#   'fieldName': 'commercial_vehicle',
#   'format': {'align': 'left'},
#   'id': 167291021,
#   'name': 'Commercial Vehicle',
#   'position': 17,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333398,
#   'width': 117},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If the traffic violation included an alcohol related ',
#   'fieldName': 'alcohol',
#   'format': {'align': 'left'},
#   'id': 167291022,
#   'name': 'Alcohol',
#   'position': 18,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333397,
#   'width': 54},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If the traffic violation was in a work zone.',
#   'fieldName': 'work_zone',
#   'format': {'align': 'left'},
#   'id': 167291023,
#   'name': 'Work Zone',
#   'position': 19,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333399,
#   'width': 69},
#  {'cachedContents': {'largest': 'XX',
#    'non_null': 1067771,
#    'null': 59,
#    'smallest': 'AB',
#    'top': [{'count': 20, 'item': 'MD'},
#     {'count': 19, 'item': 'VA'},
#     {'count': 18, 'item': 'DC'},
#     {'count': 17, 'item': 'CA'},
#     {'count': 16, 'item': 'FL'},
#     {'count': 15, 'item': 'OH'},
#     {'count': 14, 'item': 'XX'},
#     {'count': 13, 'item': 'TX'},
#     {'count': 12, 'item': 'IN'},
#     {'count': 11, 'item': 'GA'},
#     {'count': 10, 'item': 'WV'},
#     {'count': 9, 'item': 'MI'},
#     {'count': 8, 'item': 'PA'},
#     {'count': 7, 'item': 'NY'},
#     {'count': 6, 'item': 'IL'},
#     {'count': 5, 'item': 'NJ'},
#     {'count': 4, 'item': 'NC'},
#     {'count': 3, 'item': 'SC'},
#     {'count': 2, 'item': 'MA'},
#     {'count': 1, 'item': 'TN'}]},
#   'dataTypeName': 'text',
#   'description': 'State issuing the vehicle registration.',
#   'fieldName': 'state',
#   'format': {'align': 'left'},
#   'id': 167291024,
#   'name': 'State',
#   'position': 20,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333882,
#   'width': 50},
#  {'cachedContents': {'largest': '29 - Unknown',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': '01 - Motorcycle',
#    'top': [{'count': 20, 'item': '02 - Automobile'},
#     {'count': 19, 'item': '05 - Light Duty Truck'},
#     {'count': 18, 'item': '28 - Other'},
#     {'count': 17, 'item': '08 - Recreational Vehicle'},
#     {'count': 16, 'item': '29 - Unknown'},
#     {'count': 15, 'item': '03 - Station Wagon'},
#     {'count': 14, 'item': '06 - Heavy Duty Truck'},
#     {'count': 13, 'item': '07 - Truck/Road Tractor'},
#     {'count': 12, 'item': '01 - Motorcycle'},
#     {'count': 11, 'item': '25 - Utility Trailer'},
#     {'count': 10, 'item': '19 - Moped'},
#     {'count': 9, 'item': '04 - Limousine'},
#     {'count': 8, 'item': '10 - Transit Bus'},
#     {'count': 7, 'item': '20 - Commercial Rig'},
#     {'count': 6, 'item': '11 - Cross Country Bus'},
#     {'count': 5, 'item': '23 - Travel/Home Trailer'},
#     {'count': 4, 'item': '12 - School Bus'},
#     {'count': 3, 'item': '27 - Farm Equipment'},
#     {'count': 2, 'item': '21 - Tandem Trailer'},
#     {'count': 1, 'item': '13 - Ambulance(Emerg)'}]},
#   'dataTypeName': 'text',
#   'description': 'Type of vehicle (Examples: Automobile, Station Wagon, Heavy Duty Truck, etc.)',
#   'fieldName': 'vehicle_type',
#   'format': {'align': 'left'},
#   'id': 167291025,
#   'name': 'VehicleType',
#   'position': 21,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333370,
#   'width': 147},
#  {'cachedContents': {'largest': '9999',
#    'non_null': 1061153,
#    'null': 6677,
#    'smallest': '0',
#    'top': [{'count': 20, 'item': '1997'},
#     {'count': 19, 'item': '1990'},
#     {'count': 18, 'item': '1999'},
#     {'count': 17, 'item': '2016'},
#     {'count': 16, 'item': '2000'},
#     {'count': 15, 'item': '2001'},
#     {'count': 14, 'item': '2015'},
#     {'count': 13, 'item': '2013'},
#     {'count': 12, 'item': '2005'},
#     {'count': 11, 'item': '2009'},
#     {'count': 10, 'item': '2006'},
#     {'count': 9, 'item': '2008'},
#     {'count': 8, 'item': '2002'},
#     {'count': 7, 'item': '2007'},
#     {'count': 6, 'item': '2011'},
#     {'count': 5, 'item': '1996'},
#     {'count': 4, 'item': '2010'},
#     {'count': 3, 'item': '2003'},
#     {'count': 2, 'item': '2014'},
#     {'count': 1, 'item': '2012'}]},
#   'dataTypeName': 'text',
#   'description': 'Year vehicle was made.',
#   'fieldName': 'year',
#   'format': {'align': 'left'},
#   'id': 167291026,
#   'name': 'Year',
#   'position': 22,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333372,
#   'width': 54},
#  {'cachedContents': {'largest': 'ZUZU',
#    'non_null': 1067829,
#    'null': 1,
#    'smallest': '-',
#    'top': [{'count': 20, 'item': 'LEXUS'},
#     {'count': 19, 'item': 'FORD'},
#     {'count': 18, 'item': 'HONDA'},
#     {'count': 17, 'item': 'MERZ'},
#     {'count': 16, 'item': 'DODGE'},
#     {'count': 15, 'item': 'TOYOTA'},
#     {'count': 14, 'item': 'TOYT'},
#     {'count': 13, 'item': 'CHEVROLET'},
#     {'count': 12, 'item': 'CHEV'},
#     {'count': 11, 'item': 'CHEVY'},
#     {'count': 10, 'item': 'HOND'},
#     {'count': 9, 'item': 'BMW'},
#     {'count': 8, 'item': 'NISS'},
#     {'count': 7, 'item': 'JEEP'},
#     {'count': 6, 'item': 'NISSAN'},
#     {'count': 5, 'item': 'GMC'},
#     {'count': 4, 'item': 'MAZDA'},
#     {'count': 3, 'item': 'HYUNDAI'},
#     {'count': 2, 'item': 'ACURA'},
#     {'count': 1, 'item': 'KIA'}]},
#   'dataTypeName': 'text',
#   'description': 'Manufacturer of the vehicle (Examples: Ford, Chevy, Honda, Toyota, etc.)',
#   'fieldName': 'make',
#   'format': {'align': 'left'},
#   'id': 167291027,
#   'name': 'Make',
#   'position': 23,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333374,
#   'width': 88},
#  {'cachedContents': {'largest': 'ZZR1200',
#    'non_null': 1067797,
#    'null': 33,
#    'smallest': '-',
#    'top': [{'count': 20, 'item': 'TK'},
#     {'count': 19, 'item': 'ACCORD'},
#     {'count': 18, 'item': '4S'},
#     {'count': 17, 'item': 'COROLLA'},
#     {'count': 16, 'item': 'CIVIC'},
#     {'count': 15, 'item': 'CAMRY'},
#     {'count': 14, 'item': 'ALTIMA'},
#     {'count': 13, 'item': '4D'},
#     {'count': 12, 'item': '2S'},
#     {'count': 11, 'item': 'SUV'},
#     {'count': 10, 'item': 'VAN'},
#     {'count': 9, 'item': 'F150'},
#     {'count': 8, 'item': 'E350'},
#     {'count': 7, 'item': '4DR'},
#     {'count': 6, 'item': 'SENTRA'},
#     {'count': 5, 'item': 'ODYSSEY'},
#     {'count': 4, 'item': 'RAV4'},
#     {'count': 3, 'item': 'CLASSIC'},
#     {'count': 2, 'item': 'YUKON'},
#     {'count': 1, 'item': 'S550'}]},
#   'dataTypeName': 'text',
#   'description': 'Model of the vehicle.',
#   'fieldName': 'model',
#   'format': {'align': 'left'},
#   'id': 167291028,
#   'name': 'Model',
#   'position': 24,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333376,
#   'width': 100},
#  {'cachedContents': {'largest': 'YELLOW',
#    'non_null': 1066084,
#    'null': 1746,
#    'smallest': 'BEIGE',
#    'top': [{'count': 20, 'item': 'GRAY'},
#     {'count': 19, 'item': 'BLUE, LIGHT'},
#     {'count': 18, 'item': 'WHITE'},
#     {'count': 17, 'item': 'BLACK'},
#     {'count': 16, 'item': 'SILVER'},
#     {'count': 15, 'item': 'BLUE, DARK'},
#     {'count': 14, 'item': 'RED'},
#     {'count': 13, 'item': 'BLUE'},
#     {'count': 12, 'item': 'YELLOW'},
#     {'count': 11, 'item': 'GREEN'},
#     {'count': 10, 'item': 'TAN'},
#     {'count': 9, 'item': 'GOLD'},
#     {'count': 8, 'item': 'PURPLE'},
#     {'count': 7, 'item': 'BROWN'},
#     {'count': 6, 'item': 'BEIGE'},
#     {'count': 5, 'item': 'GREEN, DK'},
#     {'count': 4, 'item': 'N/A'},
#     {'count': 3, 'item': 'MAROON'},
#     {'count': 2, 'item': 'GREEN, LGT'},
#     {'count': 1, 'item': 'ORANGE'}]},
#   'dataTypeName': 'text',
#   'description': 'Color of the vehicle.',
#   'fieldName': 'color',
#   'format': {'align': 'left'},
#   'id': 167291029,
#   'name': 'Color',
#   'position': 25,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333379,
#   'width': 82},
#  {'cachedContents': {'largest': 'Warning',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'Citation',
#    'top': [{'count': 20, 'item': 'Citation'},
#     {'count': 19, 'item': 'Warning'},
#     {'count': 18, 'item': 'ESERO'},
#     {'count': 17, 'item': 'SERO'}]},
#   'dataTypeName': 'text',
#   'description': 'Violation type.  (Examples: Warning, Citation, SERO)',
#   'fieldName': 'violation_type',
#   'format': {'align': 'left'},
#   'id': 167291030,
#   'name': 'Violation Type',
#   'position': 26,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333380,
#   'width': 96},
#  {'cachedContents': {'largest': '9-337(a)',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': '10-303(a)',
#    'top': [{'count': 20, 'item': '16-303(h)'},
#     {'count': 19, 'item': '16-303(c)'},
#     {'count': 18, 'item': '13-401(h)'},
#     {'count': 17, 'item': '16-112(c)'},
#     {'count': 16, 'item': '21-801.1'},
#     {'count': 15, 'item': '16-101(a)'},
#     {'count': 14, 'item': '21-201(a1)'},
#     {'count': 13, 'item': '13-409(b)'},
#     {'count': 12, 'item': '21-707(a)'},
#     {'count': 11, 'item': '21-1124.2(d2)'},
#     {'count': 10, 'item': '13-411(f)'},
#     {'count': 9, 'item': '22-412.3(b)'},
#     {'count': 8, 'item': '21-801(a)'},
#     {'count': 7, 'item': '22-201.1'},
#     {'count': 6, 'item': '22-204(f)'},
#     {'count': 5, 'item': '22-226(a)'},
#     {'count': 4, 'item': '64*'},
#     {'count': 3, 'item': '61'},
#     {'count': 2, 'item': '56*'},
#     {'count': 1, 'item': '61*'}]},
#   'dataTypeName': 'text',
#   'description': 'Numeric code for the specific charge. ',
#   'fieldName': 'charge',
#   'format': {'align': 'left'},
#   'id': 167291031,
#   'name': 'Charge',
#   'position': 27,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333381,
#   'width': 90},
#  {'cachedContents': {'largest': 'Transportation Article',
#    'non_null': 1013474,
#    'null': 54356,
#    'smallest': 'Maryland Rules',
#    'top': [{'count': 20, 'item': 'Transportation Article'},
#     {'count': 19, 'item': 'Maryland Rules'}]},
#   'dataTypeName': 'text',
#   'description': 'Article of State Law.  (TA = Transportation Article, MR = Maryland Rules)',
#   'fieldName': 'article',
#   'format': {'align': 'left'},
#   'id': 167291032,
#   'name': 'Article',
#   'position': 28,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333382,
#   'width': 133},
#  {'cachedContents': {'largest': 'Yes',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'No',
#    'top': [{'count': 20, 'item': 'No'}, {'count': 19, 'item': 'Yes'}]},
#   'dataTypeName': 'text',
#   'description': 'If the traffic violation was a contributing factor in an accident.',
#   'fieldName': 'contributed_to_accident',
#   'format': {'align': 'left'},
#   'id': 167291033,
#   'name': 'Contributed To Accident',
#   'position': 29,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333389,
#   'width': 136},
#  {'cachedContents': {'largest': 'WHITE',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'ASIAN',
#    'top': [{'count': 20, 'item': 'BLACK'},
#     {'count': 19, 'item': 'OTHER'},
#     {'count': 18, 'item': 'WHITE'},
#     {'count': 17, 'item': 'HISPANIC'},
#     {'count': 16, 'item': 'ASIAN'},
#     {'count': 15, 'item': 'NATIVE AMERICAN'}]},
#   'dataTypeName': 'text',
#   'description': 'Race of the driver.  (Example: Asian, Black, White, Other, etc.)',
#   'fieldName': 'race',
#   'format': {'align': 'left'},
#   'id': 167291034,
#   'name': 'Race',
#   'position': 30,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333383,
#   'width': 97},
#  {'cachedContents': {'largest': 'U',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'F',
#    'top': [{'count': 20, 'item': 'M'},
#     {'count': 19, 'item': 'F'},
#     {'count': 18, 'item': 'U'}]},
#   'dataTypeName': 'text',
#   'description': 'Gender of the driver (F = Female, M = Male)',
#   'fieldName': 'gender',
#   'format': {'align': 'left'},
#   'id': 167291035,
#   'name': 'Gender',
#   'position': 31,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333384,
#   'width': 50},
#  {'cachedContents': {'largest': 'ZSILVER SPRING',
#    'non_null': 1067759,
#    'null': 71,
#    'smallest': '.',
#    'top': [{'count': 20, 'item': 'SILVER SPRING'},
#     {'count': 19, 'item': 'WASHINGTON'},
#     {'count': 18, 'item': 'GERMANTOWN'},
#     {'count': 17, 'item': 'GAITHERSBURG'},
#     {'count': 16, 'item': 'BETHESDA'},
#     {'count': 15, 'item': 'HYATTSVILLE'},
#     {'count': 14, 'item': 'LAUREL'},
#     {'count': 13, 'item': 'ROCKVILLE'},
#     {'count': 12, 'item': 'POTOMAC'},
#     {'count': 11, 'item': 'OLNEY'},
#     {'count': 10, 'item': 'MONTGOMERY VILLAGE'},
#     {'count': 9, 'item': 'FREDERICK'},
#     {'count': 8, 'item': 'CLARKSBURG'},
#     {'count': 7, 'item': 'DAMASCUS'},
#     {'count': 6, 'item': 'NORTH POTOMAC'},
#     {'count': 5, 'item': 'TAKOMA PARK'},
#     {'count': 4, 'item': 'BURTONSVILLE'},
#     {'count': 3, 'item': 'KENSINGTON'},
#     {'count': 2, 'item': 'BELTSVILLE'},
#     {'count': 1, 'item': 'BOYDS'}]},
#   'dataTypeName': 'text',
#   'description': 'City of the driver’s home address.',
#   'fieldName': 'driver_city',
#   'format': {'align': 'left'},
#   'id': 167291036,
#   'name': 'Driver City',
#   'position': 32,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333385,
#   'width': 232},
#  {'cachedContents': {'largest': 'XX',
#    'non_null': 1067819,
#    'null': 11,
#    'smallest': 'AB',
#    'top': [{'count': 20, 'item': 'MD'},
#     {'count': 19, 'item': 'DC'},
#     {'count': 18, 'item': 'VA'},
#     {'count': 17, 'item': 'NY'},
#     {'count': 16, 'item': 'SC'},
#     {'count': 15, 'item': 'CA'},
#     {'count': 14, 'item': 'OH'},
#     {'count': 13, 'item': 'PA'},
#     {'count': 12, 'item': 'IN'},
#     {'count': 11, 'item': 'MI'},
#     {'count': 10, 'item': 'TN'},
#     {'count': 9, 'item': 'FL'},
#     {'count': 8, 'item': 'WV'},
#     {'count': 7, 'item': 'MA'},
#     {'count': 6, 'item': 'NJ'},
#     {'count': 5, 'item': 'NC'},
#     {'count': 4, 'item': 'GA'},
#     {'count': 3, 'item': 'TX'},
#     {'count': 2, 'item': 'IL'},
#     {'count': 1, 'item': 'MO'}]},
#   'dataTypeName': 'text',
#   'description': 'State of the driver’s home address.',
#   'fieldName': 'driver_state',
#   'format': {'align': 'left'},
#   'id': 167291037,
#   'name': 'Driver State',
#   'position': 33,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333386,
#   'width': 66},
#  {'cachedContents': {'largest': 'XX',
#    'non_null': 1066901,
#    'null': 929,
#    'smallest': 'AB',
#    'top': [{'count': 20, 'item': 'MD'},
#     {'count': 19, 'item': 'DC'},
#     {'count': 18, 'item': 'NY'},
#     {'count': 17, 'item': 'VA'},
#     {'count': 16, 'item': 'SC'},
#     {'count': 15, 'item': 'CA'},
#     {'count': 14, 'item': 'OH'},
#     {'count': 13, 'item': 'PA'},
#     {'count': 12, 'item': 'MI'},
#     {'count': 11, 'item': 'TX'},
#     {'count': 10, 'item': 'IN'},
#     {'count': 9, 'item': 'GA'},
#     {'count': 8, 'item': 'TN'},
#     {'count': 7, 'item': 'FL'},
#     {'count': 6, 'item': 'WV'},
#     {'count': 5, 'item': 'MA'},
#     {'count': 4, 'item': 'IL'},
#     {'count': 3, 'item': 'NJ'},
#     {'count': 2, 'item': 'NC'},
#     {'count': 1, 'item': 'XX'}]},
#   'dataTypeName': 'text',
#   'description': 'State issuing the Driver’s License.',
#   'fieldName': 'dl_state',
#   'format': {'align': 'left'},
#   'id': 167291038,
#   'name': 'DL State',
#   'position': 34,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333387,
#   'width': 50},
#  {'cachedContents': {'largest': 'S - License Plate Recognition',
#    'non_null': 1067830,
#    'null': 0,
#    'smallest': 'A - Marked Patrol',
#    'top': [{'count': 20, 'item': 'A - Marked Patrol'},
#     {'count': 19, 'item': 'Q - Marked Laser'},
#     {'count': 18, 'item': 'B - Unmarked Patrol'},
#     {'count': 17, 'item': 'F - Unmarked Stationary Radar'},
#     {'count': 16, 'item': 'L - Motorcycle'},
#     {'count': 15, 'item': 'G - Marked Moving Radar (Stationary)'},
#     {'count': 14, 'item': 'R - Unmarked Laser'},
#     {'count': 13, 'item': 'H - Unmarked Moving Radar (Stationary)'},
#     {'count': 12, 'item': 'O - Foot Patrol'},
#     {'count': 11, 'item': 'S - License Plate Recognition'},
#     {'count': 10, 'item': 'I - Marked Moving Radar (Moving)'},
#     {'count': 9, 'item': 'M - Marked (Off-Duty)'},
#     {'count': 8, 'item': 'J - Unmarked Moving Radar (Moving)'},
#     {'count': 7, 'item': 'E - Marked Stationary Radar'},
#     {'count': 6, 'item': 'N - Unmarked (Off-Duty)'},
#     {'count': 5, 'item': 'C - Marked VASCAR'},
#     {'count': 4, 'item': 'D - Unmarked VASCAR'},
#     {'count': 3, 'item': 'P - Mounted Patrol'},
#     {'count': 2, 'item': 'K - Aircraft Assist'}]},
#   'dataTypeName': 'text',
#   'description': 'Type of Arrest (A = Marked, B = Unmarked, etc.)',
#   'fieldName': 'arrest_type',
#   'format': {'align': 'left'},
#   'id': 167291039,
#   'name': 'Arrest Type',
#   'position': 35,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333388,
#   'width': 208},
#  {'cachedContents': {'largest': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#     'latitude': '39.0835433333333',
#     'longitude': '-77.152665'},
#    'non_null': 980784,
#    'null': 87046,
#    'smallest': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#     'latitude': '39.0835433333333',
#     'longitude': '-77.152665'},
#    'top': [{'count': 20,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.0611333333333',
#       'longitude': '-77.0529633333333'}},
#     {'count': 19,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.0584266666667',
#       'longitude': '-77.0479483333333'}},
#     {'count': 18,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.1732183333333',
#       'longitude': '-77.2749966666667'}},
#     {'count': 17,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.1641316666667',
#       'longitude': '-77.2854233333333'}},
#     {'count': 16,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.10273',
#       'longitude': '-77.0767416666667'}},
#     {'count': 15,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.04836',
#       'longitude': '-77.05185'}},
#     {'count': 14,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.1185668333333',
#       'longitude': '-77.182816'}},
#     {'count': 13,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.073645',
#       'longitude': '-77.0664716666667'}},
#     {'count': 12,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.031945',
#       'longitude': '-77.0491'}},
#     {'count': 11,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.181995',
#       'longitude': '-77.231645'}},
#     {'count': 10,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.1876583333333',
#       'longitude': '-77.250475'}},
#     {'count': 9,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.0644266666667',
#       'longitude': '-77.073985'}},
#     {'count': 8,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.096275',
#       'longitude': '-77.202135'}},
#     {'count': 7,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.1615416666667',
#       'longitude': '-77.280335'}},
#     {'count': 6,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.0366416666667',
#       'longitude': '-77.0613516666667'}},
#     {'count': 5,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '39.0406833333333',
#       'longitude': '-77.0540533333333'}},
#     {'count': 4,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '38.9970816666667',
#       'longitude': '-77.03358'}},
#     {'count': 3,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '38.992695',
#       'longitude': '-77.0240416666667'}},
#     {'count': 2,
#      'item': {'human_address': '{"address":"","city":"","state":"","zip":""}',
#       'latitude': '38.9926883333333',
#       'longitude': '-77.02404'}}]},
#   'dataTypeName': 'location',
#   'description': 'Geo-coded location information.',
#   'fieldName': 'geolocation',
#   'format': {'align': 'left', 'view': 'address_coords'},
#   'id': 167291040,
#   'name': 'Geolocation',
#   'position': 36,
#   'renderTypeName': 'location',
#   'subColumnTypes': ['human_address',
#    'latitude',
#    'longitude',
#    'machine_address',
#    'needs_recoding'],
#   'tableColumnId': 22014969,
#   'width': 100}]

# %%
column_names = [col["fieldName"] for col in columns]
column_names
# Out:
# [':sid',
#  ':id',
#  ':position',
#  ':created_at',
#  ':created_meta',
#  ':updated_at',
#  ':updated_meta',
#  ':meta',
#  'date_of_stop',
#  'time_of_stop',
#  'agency',
#  'subagency',
#  'description',
#  'location',
#  'latitude',
#  'longitude',
#  'accident',
#  'belts',
#  'personal_injury',
#  'property_damage',
#  'fatal',
#  'commercial_license',
#  'hazmat',
#  'commercial_vehicle',
#  'alcohol',
#  'work_zone',
#  'state',
#  'vehicle_type',
#  'year',
#  'make',
#  'model',
#  'color',
#  'violation_type',
#  'charge',
#  'article',
#  'contributed_to_accident',
#  'race',
#  'gender',
#  'driver_city',
#  'driver_state',
#  'dl_state',
#  'arrest_type',
#  'geolocation']

# %%
good_columns = [
    "date_of_stop", 
    "time_of_stop", 
    "agency", 
    "subagency",
    "description",
    "location", 
    "latitude", 
    "longitude", 
    "vehicle_type", 
    "year", 
    "make", 
    "model", 
    "color", 
    "violation_type",
    "race", 
    "gender", 
    "driver_state", 
    "driver_city", 
    "dl_state",
    "arrest_type"
]

data = []
with open(filename, 'r') as f:
    objects = ijson.items(f, 'data.item')
    for row in objects:
        selected_row = []
        for item in good_columns:
            selected_row.append(row[column_names.index(item)])
        data.append(selected_row)

# %%
data[0]
# Out:
# ['2013-09-24T00:00:00',
#  '17:11:00',
#  'MCP',
#  '3rd district, Silver Spring',
#  'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#  '8804 FLOWER AVE',
#  None,
#  None,
#  '02 - Automobile',
#  '2008',
#  'FORD',
#  '4S',
#  'BLACK',
#  'Citation',
#  'BLACK',
#  'M',
#  'MD',
#  'TAKOMA PARK',
#  'MD',
#  'A - Marked Patrol']

# %%
import pandas as pd

stops = pd.DataFrame(data, columns=good_columns)

# %%
stops
# Out:
#                 date_of_stop time_of_stop agency  \
# 7            DRIVING UNDER THE INFLUENCE OF ALCOHOL PER SE
# 8        PERSON DRIVING MOTOR VEHICLE WHILE LICENSE SUS...
# 9                      OPERATOR NOT RESTRAINED BY SEATBELT
# 10       NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 11       DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 12       DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 13       PERSON DRIVING MOTOR VEHICLE WHILE LICENSE SUS...
# 14       FAILURE TO DRIVE ON RIGHT HAND ROADWAY OF DIVI...
# 15       DRIVING VEHICLE ON HIGHWAY WITH AN EXPIRED LIC...
# 16       PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT I...
# 17       DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF A...
# 18       DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 19       FAILURE TO ATTACH VEHICLE REGISTRATION PLATES ...
# 20       DRIVER FAILURE TO YIELD RIGHT OF WAY ENTERING ...
# 21                            FAILURE TO STOP AT STOP SIGN
# 22       DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 23       FAILURE TO RETURN TO & REMAIN AT SCENE OF ACCI...
# 24       EXCEEDING MAXIMUM SPEED: 49 MPH IN A POSTED 40...
# 25       PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...
# 26       PERSON DRIVING MOTOR VEHICLE WHILE LICENSE SUS...
# 27       DRIVER WHEN TURNING LEFT FAIL TO YIELD RIGHT O...
# 28       FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION O...
# 29       DRIVING VEHICLE ON HIGHWAY WITH AN EXPIRED LIC...
# ...                                                    ...
# 1067800  OPERATING VEHICLE ON HIGHWAY WITH UNAUTHORIZED...
# 1067801  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 1067802  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 1067803  DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 1067804  DRIVER USE OF MOTOR VEH. HORN ON HWY. WHEN NOT...
# 1067805         EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH
# 1067806  FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DI...
# 1067807  DISPLAYING EXPIRED REGISTRATION PLATE ISSUED B...
# 1067808  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 1067809         EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH
# 1067810                                        WINDOW TINT
# 1067811                                        WINDOW TINT
# 1067812                                        WINDOW TINT
# 1067813                                        WINDOW TINT
# 1067814                                    STOP LIGHTS (*)
# 1067815                                     TAILLIGHTS (*)
# 1067816                                          GLASS (*)
# 1067817                                    STOP LIGHTS (*)
# 1067818                                     HEADLIGHTS (*)
# 1067819                                    STOP LIGHTS (*)
# 1067820                                     TAILLIGHTS (*)
# 1067821                                    STOP LIGHTS (*)
# 1067822                                     HEADLIGHTS (*)
# 1067823                                     EXHAUST SYSTEM
# 21          CALIBER      ORANGE       Citation     BLACK      M           MD
# 22               TK  BLUE, DARK       Citation     ASIAN      F           MD
# 23            CAMRY       BLACK       Citation     BLACK      M           MD
# 24               4S        GOLD       Citation     OTHER      M           MD
# 25        ECONOLINE       WHITE       Citation  HISPANIC      M           MD
# 26            RX300       WHITE       Citation     WHITE      F           MD
# 27               HY        BLUE       Citation     BLACK      F           MD
# 28       GRAND PRIX       BLACK       Citation     WHITE      F           MD
# 29               4S       BLACK       Citation     BLACK      M           DC
# ...             ...         ...            ...       ...    ...          ...
# 1067800     COROLLA      SILVER        Warning     WHITE      M           MD
# 1067801         VAN       WHITE        Warning     ASIAN      M           VA
# 1067802          RL       WHITE        Warning     WHITE      F           MD
# 1067803       NV200       WHITE        Warning     WHITE      F           MD
# 1067804       ROGUE      MAROON        Warning     ASIAN      M           MD
# 1067805        FX35  BLUE, DARK        Warning     BLACK      M           MD
# 1067806  MOUNTANEER       WHITE        Warning     WHITE      F           MD
# 1067807  MOUNTANEER       WHITE        Warning     WHITE      F           MD
# 1067808   SILVERADO        BLUE        Warning     WHITE      M           TX
# 1067809         CRV  BLUE, DARK        Warning     WHITE      M           MD
# 1067810      PASSAT      SILVER          ESERO     ASIAN      F           MD
# 1067811          4S       BLACK          ESERO     ASIAN      M           MD
# 1067812      MAXIMA       BLACK          ESERO     WHITE      M           MD
# 1067813    SUBURBAN       BLACK          ESERO     BLACK      M           MD
# 1067814          TK       BLACK          ESERO     WHITE      M           MD
# 1067815          TK       WHITE          ESERO     WHITE      M           MD
# 1067816          4S      SILVER          ESERO  HISPANIC      F           MD
# 1067817      SONATA       BLACK          ESERO     WHITE      M           MD
# 1067818          TK       BLACK          ESERO     WHITE      F           MD
# 1067819      SONATA         RED          ESERO     WHITE      F           MD
# 1067820    FORESTER      MAROON          ESERO     ASIAN      F           MD
# 1067821      ACCORD         RED          ESERO     BLACK      F           MD
# 1067822          4S       BLACK          ESERO     WHITE      M           MD
# 1067823       2.3CL       WHITE          ESERO  HISPANIC      F           MD
# 1067824          4S        GRAY          ESERO     WHITE      F           MD
# 1067825      RANGER        BLUE          ESERO     WHITE      M           VA
# 1067826          TK       BLACK          ESERO  HISPANIC      F           MD
# 1067827     COROLLA        GRAY          ESERO     WHITE      M           MD
# 1067828      ALTIMA        GRAY          ESERO     BLACK      M           DC
# 1067829          4S      SILVER          ESERO     BLACK      M           MD
#
#                 driver_city dl_state          arrest_type
# 0               TAKOMA PARK       MD    A - Marked Patrol
# 1                   DERWOOD       MD    A - Marked Patrol
# 2                GERMANTOWN       MD    A - Marked Patrol
# 3                 ARLINGTON       VA    A - Marked Patrol
# 4            UPPER MARLBORO       MD    A - Marked Patrol
# 5             SILVER SPRING       MD    A - Marked Patrol
# 6             SILVER SPRING       MD    A - Marked Patrol
# 7             SILVER SPRING       MD    A - Marked Patrol
# 8                GERMANTOWN       MD    A - Marked Patrol
# 9              OWINGS MILLS       MD    A - Marked Patrol
# 10            SILVER SPRING       MD    A - Marked Patrol
# 11               BELTSVILLE       MD    A - Marked Patrol
# 12            SILVER SPRING       MD    A - Marked Patrol
# 13            SILVER SPRING       MD    A - Marked Patrol
# 14            POINT OF ROCK       WV    A - Marked Patrol
# 15                 LANDOVER       MD    A - Marked Patrol
# 16            SILVER SPRING       MD      O - Foot Patrol
# 17                BALTIMORE       MD    A - Marked Patrol
# 18               WASHINGTON       DC    A - Marked Patrol
# 19               BELTSVILLE       MD    A - Marked Patrol
# 20             GAITHERSBURG       MD    A - Marked Patrol
# 21                OXON HILL       MD    A - Marked Patrol
# 22            SILVER SPRING       MD    A - Marked Patrol
# 23                ROCKVILLE       MD    A - Marked Patrol
# 24              TAKOMA PARK       MD     Q - Marked Laser
# 25                ROCKVILLE       MD    A - Marked Patrol
# 26       MONTGOMERY VILLAGE       MD    A - Marked Patrol
# 27              FORESTVILLE       MD    A - Marked Patrol
# 28             COLLEGE PARK       MD    A - Marked Patrol
# 29               WASHINGTON       DC    A - Marked Patrol
# ...                     ...      ...                  ...
# 1067800           ROCKVILLE       MD    A - Marked Patrol
# 1067801              VIENNA       VA  B - Unmarked Patrol
# 1067802           DICKERSON       MD  B - Unmarked Patrol
# 1067803           FREDERICK       MD  B - Unmarked Patrol
# 1067804       SILVER SPRING       MD  B - Unmarked Patrol
# 1067805       SILVER SPRING       MD     Q - Marked Laser
# 1067806        GAITHERSBURG       MD    A - Marked Patrol
# 1067807        GAITHERSBURG       MD    A - Marked Patrol
# 1067808               WYLIE       TX    A - Marked Patrol
# 1067809          MOUNT AIRY       MD    A - Marked Patrol
# 1067810        GAITHERSBURG       MD    A - Marked Patrol
# 1067811       SILVER SPRING       MD    A - Marked Patrol
# 1067812        GAITHERSBURG       MD    A - Marked Patrol
# 1067813          GERMANTOWN       MD    A - Marked Patrol
# 1067814            BETHESDA       MD    A - Marked Patrol
# 1067815               BOWIE       MD    A - Marked Patrol
# 1067816         HYATTSVILLE       MD    A - Marked Patrol
# 1067817             CORDOVA       MD    A - Marked Patrol
# 1067818           ROCKVILLE       MD    A - Marked Patrol
# 1067819        GAITHERSBURG       MD    A - Marked Patrol
# 1067820           ROCKVILLE       MD    A - Marked Patrol
# 1067821       SILVER SPRING       MD    A - Marked Patrol
# 1067822       SILVER SPRING       MD    A - Marked Patrol
# 1067823          GLENN DALE       MD    A - Marked Patrol
# 1067824          GERMANTOWN       MD    A - Marked Patrol
# 1067825             FAIRFAX       VA    A - Marked Patrol
# 1067826       SILVER SPRING       MD    A - Marked Patrol
# 1067827  MONTGOMERY VILLAGE       MD    A - Marked Patrol
# 1067828          WASHINGTON       DC    A - Marked Patrol
# 1067829            ACCOKEEK       MD    A - Marked Patrol
#
# [1067830 rows x 20 columns]

# %%
stops["color"].value_counts()
# Out:
# BLACK          210836
# SILVER         195444
# WHITE          160592
# GRAY           113575
# RED             84650
# BLUE            78722
# GREEN           43303
# GOLD            35162
# TAN             23470
# BLUE, DARK      22735
# MAROON          18903
# BLUE, LIGHT     14651
# BEIGE           12922
# GREEN, DK       12586
# N/A             12242
# GREEN, LGT       6356
# BROWN            5136
# YELLOW           4142
# ORANGE           3735
# BRONZE           2530
# PURPLE           2189
# MULTICOLOR        912
# CREAM             735
# COPPER            347
# PINK              166
# CHROME             23
# CAMOUFLAGE         20
# Name: color, dtype: int64

# %%
import numpy as np

def parse_float(x):
    try:
        x = float(x)
    except Exception:
        x = 0
    return x
stops["longitude"] = stops["longitude"].apply(parse_float)
stops["latitude"] = stops["latitude"].apply(parse_float)

# %%
import datetime
def parse_full_date(row):
    date = datetime.datetime.strptime(row["date_of_stop"], "%Y-%m-%dT%H:%M:%S")
    time = row["time_of_stop"].split(":")
    date = date.replace(hour=int(time[0]), minute = int(time[1]), second = int(time[2]))
    return date

stops["date"] = stops.apply(parse_full_date, axis=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.hist(stops["date"].dt.weekday, bins=6)
# Out:
# (array([ 144318.,  183209.,  171866.,  164871.,  169300.,  234266.]),
#  array([ 0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  <a list of 6 Patch objects>)

# %%
plt.hist(stops["date"].dt.hour, bins=24)
# Out:
# (array([ 58226.,  47329.,  36223.,  23901.,  14649.,   9790.,  15843.,
#          37951.,  58013.,  53640.,  54314.,  45724.,  42391.,  43065.,
#          44810.,  37897.,  51027.,  53085.,  41935.,  37320.,  41671.,
#          58421.,  81080.,  79525.]),
#  array([  0.        ,   0.95833333,   1.91666667,   2.875     ,
#           3.83333333,   4.79166667,   5.75      ,   6.70833333,
#           7.66666667,   8.625     ,   9.58333333,  10.54166667,
#          11.5       ,  12.45833333,  13.41666667,  14.375     ,
#          15.33333333,  16.29166667,  17.25      ,  18.20833333,
#          19.16666667,  20.125     ,  21.08333333,  22.04166667,  23.        ]),
#  <a list of 24 Patch objects>)

# %%
#we selected all of the rows that came in the past year. 
last_year = stops[stops["date"] > datetime.datetime(year=2015, month=2, day=18)]

# %%
#only select rows that occurred during rush hour – the morning period when everyone is going to work
morning_rush = last_year[(last_year["date"].dt.weekday < 5) & (last_year["date"].dt.hour > 5) & 
                         (last_year["date"].dt.hour < 10)]
print(morning_rush.shape)
last_year.shape
# Out:
# (60358, 21)
# (473329, 21)

# %%
import folium
from folium import plugins

stops_map = folium.Map(location=[39.0836, -77.1483], zoom_start=11)
marker_cluster = folium.MarkerCluster().add_to(stops_map)
for name, row in morning_rush.iloc[:1000].iterrows():
    folium.Marker([row["longitude"], row["latitude"]], popup=row["description"]).add_to(marker_cluster)
stops_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stops_heatmap = folium.Map(location=[39.0836, -77.1483], zoom_start=11)
stops_heatmap.add_children(plugins.HeatMap([[row["longitude"], row["latitude"]] for name, row in morning_rush.iloc[:1000].iterrows()]))
stops_heatmap.save("heatmap.html")
stops_heatmap
# Out:
# /Users/sarveshrawat/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   app.launch_new_instance()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
